# %%
pip install pandas==0.22

# %%
import pandas as pd
import numpy  as np
import seaborn as sns
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# # Importing dataset

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %% [markdown]
# # Shape

# %%
df.shape
# Out:
# (50, 7)

# %% [markdown]
# This dataset has 50 rows and 7 columns

# %% [markdown]
# # Mean
# Mean is calculated as sum of observations by number of observations in a given data set.
#
#
# Here lets take an example of mean of No_of_Earning_Members from datasset

# %%
df['No_of_Earning_Members'].mean()
# Out:
# 1.46

# %% [markdown]
# # Median
# Median is the middle term of the given dataset
#
# here we take the example of Annual_HH_Income median

# %%
df['Annual_HH_Income'].median()
# Out:
# 447420.0

# %% [markdown]
# # Mode
# Mode is the repeatdlt occuring number in the given dataset.
#
# lets find mode of Highest_Qualified_Member

# %%
df['Highest_Qualified_Member'].mode()
# Out:
# 0    Graduate
# dtype: object

# %% [markdown]
# # Variance
# It explains the spread of data in data set.
#
# lets see an example for variance

# %%
df['Mthly_HH_Expense'].var()
# Out:
# 146173342.85714287

# %% [markdown]
# # Standard deviation
# It measures ,how far does the value is from the mean.
#
# lets see an example for standard deviaton

# %%
df['Mthly_HH_Expense'].std()
# Out:
# 12090.216824240286

# %% [markdown]
# # Correlation
# Correlation explains us how much does two variables are related to eachother.
#
# Here we can see the correlation between different variables

# %%
df.corr()
# Out:
#                        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  \
# Mthly_HH_Income               1.000000          0.649215           0.448317
# Mthly_HH_Expense              0.649215          1.000000           0.639702
# No_of_Fly_Members             0.448317          0.639702           1.000000
# Emi_or_Rent_Amt               0.036976          0.405280           0.085808
# Annual_HH_Income              0.970315          0.591222           0.430868
# No_of_Earning_Members         0.347883          0.311915           0.597482
#
#                        Emi_or_Rent_Amt  Annual_HH_Income  \
# Mthly_HH_Income               0.036976          0.970315
# Mthly_HH_Expense              0.405280          0.591222
# No_of_Fly_Members             0.085808          0.430868
# Emi_or_Rent_Amt               1.000000          0.002716
# Annual_HH_Income              0.002716          1.000000
# No_of_Earning_Members        -0.097431          0.296679
#
# ...

# %% [markdown]
# # Normal distribution
# Normal distribution  is a probability distribution that is symmetric about the mean,
# showing that data near the mean are more frequent in occurrence than data far from the mean.
# In graph form, normal distribution will appear as a bell curve.

# %% [markdown]
# ![](http://www.mathnstuff.com/math/spoken/here/2class/90/norline.gif)

# %%
sns.displot(df['Mthly_HH_Income'])

# %%
sns.displot(df['Mthly_HH_Expense'])

# %%
sns.displot(df['No_of_Fly_Members'])

# %%
sns.displot(df['Emi_or_Rent_Amt'])

# %%
sns.displot(df['Annual_HH_Income'])

# %%
sns.displot(df['No_of_Earning_Members'])

# %% [markdown]
# # Probability and A Normal Distribution
#
# The number line is marked in terms of the mean and the standard deviation.
#
# ![](http://www.mathnstuff.com/math/spoken/here/2class/90/statpb.gif)
#
#  Since normally distributed data is spread in terms of the mean and standard deviation, the percent of scores, within the same region, remains the same from normal distribution to normal distribution.

# %% [markdown]
# # Feature of Normal Distribution
#
# The main features of Normal distribution are mode and standard deviation.These determine the shape and probabilities of the distribution.
#
#
# ### 1. Mean
# The mean is used by researchers as a measure of central tendency. It can be used to describe the distribution of variables measured as ratios or intervals. In a normal distribution graph, the mean defines the location of the peak, and most of the data points are clustered around the mean. Any changes made to the value of the mean move the curve either to the left or right along the X-axis.
#
#
#
# ### 2. Standard Deviation
# The standard deviation measures the dispersion of the data points relative to the mean. It determines how far away from the mean the data points are positioned and represents the distance between the mean and the observations.

# %% [markdown]
# # Positively Skewed & Negatively Skewed Normal Distribution
# ### Skewed Distribution:
#   If one tail is longer than another, the distribution is skewed. These distributions are sometimes called asymmetric or asymmetrical distributions as they don’t show any kind of symmetry. Symmetry means that one half of the distribution is a mirror image of the other half.
#
#  ### Positively Skewed :
#  In statistics, a positively skewed (or right-skewed) distribution is a type of distribution in which most values are clustered around the left tail of the distribution while the right tail of the distribution is longer.
#  ### Negatively Skewed:
#  Negatively skewed distribution refers to the distribution type where the more values are plotted on the right side of the graph, where the tail of the distribution is longer on the left
#
#
#
#  ![](https://develve.net/files/grafskewness.gif)

# %% [markdown]
# # Effect on Mean, Median and Mode due to Skewness
#
# if the distribution of data is skewed to the left, the mean is less than the median, which is often less than the mode. If the distribution of data is skewed to the right, the mode is often less than the median, which is less than the mean.
#
#
# ![](https://miro.medium.com/max/694/1*d318NxKHGZgWTHvKjbzJ_g.jpeg)
#
# ![](https://miro.medium.com/max/720/1*zMSuf2Y_DFjdQzMrKU-oGQ.jpeg)

# %% [markdown]
# # Q-Q Plot
#
# Q-Q Plot  is a graphical method of comparing two probability distributons by plotting their quantiles each other.
#
# if we compare similar distributions, then the plot will be similar to a straight line .
#
#
# ![](https://www.itl.nist.gov/div898/handbook/eda/section3/gif/qqplot.gif)

# %%
sm.qqplot(df['Mthly_HH_Income'])

# %%
sm.qqplot(df['Mthly_HH_Expense'])

# %%
sm.qqplot(df['No_of_Fly_Members'])

# %%
sm.qqplot(df['Emi_or_Rent_Amt'])

# %%
sm.qqplot(df['Annual_HH_Income'])

# %%
sm.qqplot(df['Highest_Qualified_Member'])

# %%
sm.qqplot(df['No_of_Earning_Members'])

# %% [markdown]
# #  Box Cox
#
# A Box Cox is a transformation of a non-normal dependent variables into a normal shape. Normality is an important assumption for many statistical techniques.
#    If your data isn't normal, applying a Box-Cox helps to transform u r data into normal.
#
#   ![](https://miro.medium.com/max/875/1*M9ArFYJ1yF5BONXlfFf7Cw.png)

# %%
updated=stats.boxcox(df['Mthly_HH_Expense'])

# %%
sns.displot(updated)

# %%
sns.displot(df['Mthly_HH_Expense'])

# %% [markdown]
#  Original graph and box cox transformed graphs are plotted above.Here we can observe the transformation in graphs
